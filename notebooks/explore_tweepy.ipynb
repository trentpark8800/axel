# %%
from configparser import ConfigParser
from typing import List
from tweepy import OAuthHandler, API, Cursor
import pandas as pd
from pandas import DataFrame
import datetime as dt
import time

# %%
def config_api(config_path: str) -> API:

    config: ConfigParser = ConfigParser()
    config.read(config_path)

    consumer_key = config.get("TwitterAPI", "api_key")
    consumer_secret = config.get("TwitterAPI", "api_secret_key")
    access_token = config.get("TwitterAPI", "access_token")
    access_token_secret = config.get("TwitterAPI", "access_token_secret")

    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = API(auth, wait_on_rate_limit=True)

    return api

# %%
api: API = config_api("./credentials.ini")

# Create a specific query for twitter cursor
query = "$JSESBK exclude:retweets exclude:replies"
# Specify longitude, latitude and radius to search
geocode = "-28.8166236,24.991639,1000km"

# %%
tweets = Cursor(api.search, q=query, geocode=geocode, tweet_mode='extended').items(10)

# %%
from pprint import pprint
for tweet in tweets:
    pprint(tweet._json)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Jul 21 08:18:33 +0000 2021',
#  'display_text_range': [0, 66],
#  'entities': {'hashtags': [{'indices': [0, 13], 'text': 'StandardBank'}],
#               'media': [{'display_url': 'pic.twitter.com/qF9syBGG1d',
#                          'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1417760899507507207/photo/1',
#                          'id': 1417760897435541506,
#                          'id_str': '1417760897435541506',
#                          'indices': [67, 90],
#                          'media_url': 'http://pbs.twimg.com/media/E6zmBkwVoAIUd9m.png',
#                          'media_url_https': 'https://pbs.twimg.com/media/E6zmBkwVoAIUd9m.png',
#                          'sizes': {'large': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'medium': {'h': 300,
#                                               'resize': 'fit',
#                                               'w': 600},
#                                    'small': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/qF9syBGG1d'}],
#               'symbols': [{'indices': [14, 21], 'text': 'JSESBK'}],
#               'urls': [{'display_url': 'dlvr.it/S47VcQ',
#                         'expanded_url': 'http://dlvr.it/S47VcQ',
#                         'indices': [43, 66],
#                         'url': 'https://t.co/MYHIDhB5Bs'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/qF9syBGG1d',
#                                   'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1417760899507507207/photo/1',
#                                   'id': 1417760897435541506,
#                                   'id_str': '1417760897435541506',
#                                   'indices': [67, 90],
#                                   'media_url': 'http://pbs.twimg.com/media/E6zmBkwVoAIUd9m.png',
#                                   'media_url_https': 'https://pbs.twimg.com/media/E6zmBkwVoAIUd9m.png',
#                                   'sizes': {'large': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'medium': {'h': 300,
#                                                        'resize': 'fit',
#                                                        'w': 600},
#                                             'small': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/qF9syBGG1d'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': '#StandardBank $JSESBK - View news article: '
#               'https://t.co/MYHIDhB5Bs https://t.co/qF9syBGG1d',
#  'geo': None,
#  'id': 1417760899507507207,
#  'id_str': '1417760899507507207',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Jan 12 11:41:09 +0000 2016',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'JSE SENS News\t@TimBukOneSENS\n'
#                          'Cautionary SENS\t@TimBukOneCA\n'
#                          'Director Dealings\t@TimBukOneDD\n'
#                          'Home Page \t\t@TimBukOne',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'TimBukOne.com',
#                                          'expanded_url': 'http://www.TimBukOne.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/xxbN0CscSv'}]}},
#           'favourites_count': 1,
#           'follow_request_sent': False,
#           'followers_count': 4601,
#           'following': False,
#           'friends_count': 6,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 4783839322,
#           'id_str': '4783839322',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 26,
#           'location': 'South Africa',
#           'name': 'TimBukOne News',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4783839322/1588258503',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_link_color': '007E4D',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'TimBukOneNEWS',
#           'statuses_count': 10740,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/xxbN0CscSv',
#           'utc_offset': None,
#           'verified': False,
#           'withheld_in_countries': []}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Jul 21 02:59:28 +0000 2021',
#  'display_text_range': [0, 275],
#  'entities': {'hashtags': [{'indices': [244, 257], 'text': 'StandardBank'},
#                            {'indices': [258, 262], 'text': 'JSE'},
#                            {'indices': [263, 275], 'text': 'SouthAfrica'}],
#               'symbols': [{'indices': [0, 7], 'text': 'JSESBK'}],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': '$JSESBK (Standard Bank) is in a downward trend after rejection '
#               'at the 5-yr avg. price at R136.70. Outlook remains on the '
#               'downside and will only be invalidated by a weekly close above '
#               'R142.49. Current price is: R120.87. Price targets at R81.77. '
#               '#StandardBank #JSE #SouthAfrica',
#  'geo': None,
#  'id': 1417680596386652163,
#  'id_str': '1417680596386652163',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web '
#            'App</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Sep 28 05:04:13 +0000 2014',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'Investor in the JSE 🇿🇦  &  ASX 🇦🇺',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 10853,
#           'follow_request_sent': False,
#           'followers_count': 498,
#           'following': False,
#           'friends_count': 299,
#           'geo_enabled': True,
#           'has_extended_profile': True,
#           'id': 2788492355,
#           'id_str': '2788492355',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 10,
#           'location': 'Johannesburg, South Africa',
#           'name': 'Njabs',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2788492355/1545751553',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1332969706937085963/FNsTQrCV_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1332969706937085963/FNsTQrCV_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'Njabs_GP',
#           'statuses_count': 15773,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False,
#           'withheld_in_countries': []}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jul 16 07:03:04 +0000 2021',
#  'display_text_range': [0, 66],
#  'entities': {'hashtags': [{'indices': [0, 13], 'text': 'StandardBank'}],
#               'media': [{'display_url': 'pic.twitter.com/ngPtKP3Uck',
#                          'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415929962222161923/photo/1',
#                          'id': 1415929960011681794,
#                          'id_str': '1415929960011681794',
#                          'indices': [67, 90],
#                          'media_url': 'http://pbs.twimg.com/media/E6Zky_VUUAIwwOB.png',
#                          'media_url_https': 'https://pbs.twimg.com/media/E6Zky_VUUAIwwOB.png',
#                          'sizes': {'large': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'medium': {'h': 300,
#                                               'resize': 'fit',
#                                               'w': 600},
#                                    'small': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/ngPtKP3Uck'}],
#               'symbols': [{'indices': [14, 21], 'text': 'JSESBK'}],
#               'urls': [{'display_url': 'dlvr.it/S3qgWs',
#                         'expanded_url': 'http://dlvr.it/S3qgWs',
#                         'indices': [43, 66],
#                         'url': 'https://t.co/Q21wYNI76E'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/ngPtKP3Uck',
#                                   'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415929962222161923/photo/1',
#                                   'id': 1415929960011681794,
#                                   'id_str': '1415929960011681794',
#                                   'indices': [67, 90],
#                                   'media_url': 'http://pbs.twimg.com/media/E6Zky_VUUAIwwOB.png',
#                                   'media_url_https': 'https://pbs.twimg.com/media/E6Zky_VUUAIwwOB.png',
#                                   'sizes': {'large': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'medium': {'h': 300,
#                                                        'resize': 'fit',
#                                                        'w': 600},
#                                             'small': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/ngPtKP3Uck'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': '#StandardBank $JSESBK - View news article: '
#               'https://t.co/Q21wYNI76E https://t.co/ngPtKP3Uck',
#  'geo': None,
#  'id': 1415929962222161923,
#  'id_str': '1415929962222161923',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Jan 12 11:41:09 +0000 2016',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'JSE SENS News\t@TimBukOneSENS\n'
#                          'Cautionary SENS\t@TimBukOneCA\n'
#                          'Director Dealings\t@TimBukOneDD\n'
#                          'Home Page \t\t@TimBukOne',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'TimBukOne.com',
#                                          'expanded_url': 'http://www.TimBukOne.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/xxbN0CscSv'}]}},
#           'favourites_count': 1,
#           'follow_request_sent': False,
#           'followers_count': 4601,
#           'following': False,
#           'friends_count': 6,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 4783839322,
#           'id_str': '4783839322',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 26,
#           'location': 'South Africa',
#           'name': 'TimBukOne News',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4783839322/1588258503',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_link_color': '007E4D',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'TimBukOneNEWS',
#           'statuses_count': 10740,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/xxbN0CscSv',
#           'utc_offset': None,
#           'verified': False,
#           'withheld_in_countries': []}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jul 16 05:44:33 +0000 2021',
#  'display_text_range': [0, 66],
#  'entities': {'hashtags': [{'indices': [0, 13], 'text': 'StandardBank'}],
#               'media': [{'display_url': 'pic.twitter.com/eDf87cMRpX',
#                          'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415910204860817408/photo/1',
#                          'id': 1415910203304726532,
#                          'id_str': '1415910203304726532',
#                          'indices': [67, 90],
#                          'media_url': 'http://pbs.twimg.com/media/E6ZS0_3UUAQD3xh.png',
#                          'media_url_https': 'https://pbs.twimg.com/media/E6ZS0_3UUAQD3xh.png',
#                          'sizes': {'large': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'medium': {'h': 300,
#                                               'resize': 'fit',
#                                               'w': 600},
#                                    'small': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/eDf87cMRpX'}],
#               'symbols': [{'indices': [14, 21], 'text': 'JSESBK'}],
#               'urls': [{'display_url': 'dlvr.it/S3qV2L',
#                         'expanded_url': 'http://dlvr.it/S3qV2L',
#                         'indices': [43, 66],
#                         'url': 'https://t.co/sEWMNMCnwl'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/eDf87cMRpX',
#                                   'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415910204860817408/photo/1',
#                                   'id': 1415910203304726532,
#                                   'id_str': '1415910203304726532',
#                                   'indices': [67, 90],
#                                   'media_url': 'http://pbs.twimg.com/media/E6ZS0_3UUAQD3xh.png',
#                                   'media_url_https': 'https://pbs.twimg.com/media/E6ZS0_3UUAQD3xh.png',
#                                   'sizes': {'large': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'medium': {'h': 300,
#                                                        'resize': 'fit',
#                                                        'w': 600},
#                                             'small': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/eDf87cMRpX'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': '#StandardBank $JSESBK - View news article: '
#               'https://t.co/sEWMNMCnwl https://t.co/eDf87cMRpX',
#  'geo': None,
#  'id': 1415910204860817408,
#  'id_str': '1415910204860817408',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Jan 12 11:41:09 +0000 2016',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'JSE SENS News\t@TimBukOneSENS\n'
#                          'Cautionary SENS\t@TimBukOneCA\n'
#                          'Director Dealings\t@TimBukOneDD\n'
#                          'Home Page \t\t@TimBukOne',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'TimBukOne.com',
#                                          'expanded_url': 'http://www.TimBukOne.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/xxbN0CscSv'}]}},
#           'favourites_count': 1,
#           'follow_request_sent': False,
#           'followers_count': 4601,
#           'following': False,
#           'friends_count': 6,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 4783839322,
#           'id_str': '4783839322',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 26,
#           'location': 'South Africa',
#           'name': 'TimBukOne News',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4783839322/1588258503',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_link_color': '007E4D',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'TimBukOneNEWS',
#           'statuses_count': 10740,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/xxbN0CscSv',
#           'utc_offset': None,
#           'verified': False,
#           'withheld_in_countries': []}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jul 16 05:35:03 +0000 2021',
#  'display_text_range': [0, 66],
#  'entities': {'hashtags': [{'indices': [0, 13], 'text': 'StandardBank'}],
#               'media': [{'display_url': 'pic.twitter.com/DxX9E7itYk',
#                          'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415907812069109760/photo/1',
#                          'id': 1415907810135576579,
#                          'id_str': '1415907810135576579',
#                          'indices': [67, 90],
#                          'media_url': 'http://pbs.twimg.com/media/E6ZQpsnVEAM2_9z.png',
#                          'media_url_https': 'https://pbs.twimg.com/media/E6ZQpsnVEAM2_9z.png',
#                          'sizes': {'large': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'medium': {'h': 300,
#                                               'resize': 'fit',
#                                               'w': 600},
#                                    'small': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/DxX9E7itYk'}],
#               'symbols': [{'indices': [14, 21], 'text': 'JSESBK'}],
#               'urls': [{'display_url': 'dlvr.it/S3qT7p',
#                         'expanded_url': 'http://dlvr.it/S3qT7p',
#                         'indices': [43, 66],
#                         'url': 'https://t.co/1MUdHHgQvW'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/DxX9E7itYk',
#                                   'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415907812069109760/photo/1',
#                                   'id': 1415907810135576579,
#                                   'id_str': '1415907810135576579',
#                                   'indices': [67, 90],
#                                   'media_url': 'http://pbs.twimg.com/media/E6ZQpsnVEAM2_9z.png',
#                                   'media_url_https': 'https://pbs.twimg.com/media/E6ZQpsnVEAM2_9z.png',
#                                   'sizes': {'large': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'medium': {'h': 300,
#                                                        'resize': 'fit',
#                                                        'w': 600},
#                                             'small': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/DxX9E7itYk'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': '#StandardBank $JSESBK - View news article: '
#               'https://t.co/1MUdHHgQvW https://t.co/DxX9E7itYk',
#  'geo': None,
#  'id': 1415907812069109760,
#  'id_str': '1415907812069109760',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Jan 12 11:41:09 +0000 2016',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'JSE SENS News\t@TimBukOneSENS\n'
#                          'Cautionary SENS\t@TimBukOneCA\n'
#                          'Director Dealings\t@TimBukOneDD\n'
#                          'Home Page \t\t@TimBukOne',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'TimBukOne.com',
#                                          'expanded_url': 'http://www.TimBukOne.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/xxbN0CscSv'}]}},
#           'favourites_count': 1,
#           'follow_request_sent': False,
#           'followers_count': 4601,
#           'following': False,
#           'friends_count': 6,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 4783839322,
#           'id_str': '4783839322',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 26,
#           'location': 'South Africa',
#           'name': 'TimBukOne News',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4783839322/1588258503',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_link_color': '007E4D',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'TimBukOneNEWS',
#           'statuses_count': 10740,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/xxbN0CscSv',
#           'utc_offset': None,
#           'verified': False,
#           'withheld_in_countries': []}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jul 16 05:14:04 +0000 2021',
#  'display_text_range': [0, 66],
#  'entities': {'hashtags': [{'indices': [0, 13], 'text': 'StandardBank'}],
#               'media': [{'display_url': 'pic.twitter.com/pQob918gpV',
#                          'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415902532342214656/photo/1',
#                          'id': 1415902530815492098,
#                          'id_str': '1415902530815492098',
#                          'indices': [67, 90],
#                          'media_url': 'http://pbs.twimg.com/media/E6ZL2ZnVgAIelLU.png',
#                          'media_url_https': 'https://pbs.twimg.com/media/E6ZL2ZnVgAIelLU.png',
#                          'sizes': {'large': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'medium': {'h': 300,
#                                               'resize': 'fit',
#                                               'w': 600},
#                                    'small': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/pQob918gpV'}],
#               'symbols': [{'indices': [14, 21], 'text': 'JSESBK'}],
#               'urls': [{'display_url': 'dlvr.it/S3qQvV',
#                         'expanded_url': 'http://dlvr.it/S3qQvV',
#                         'indices': [43, 66],
#                         'url': 'https://t.co/bL8UVvwclO'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/pQob918gpV',
#                                   'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415902532342214656/photo/1',
#                                   'id': 1415902530815492098,
#                                   'id_str': '1415902530815492098',
#                                   'indices': [67, 90],
#                                   'media_url': 'http://pbs.twimg.com/media/E6ZL2ZnVgAIelLU.png',
#                                   'media_url_https': 'https://pbs.twimg.com/media/E6ZL2ZnVgAIelLU.png',
#                                   'sizes': {'large': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'medium': {'h': 300,
#                                                        'resize': 'fit',
#                                                        'w': 600},
#                                             'small': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/pQob918gpV'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': '#StandardBank $JSESBK - View news article: '
#               'https://t.co/bL8UVvwclO https://t.co/pQob918gpV',
#  'geo': None,
#  'id': 1415902532342214656,
#  'id_str': '1415902532342214656',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Jan 12 11:41:09 +0000 2016',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'JSE SENS News\t@TimBukOneSENS\n'
#                          'Cautionary SENS\t@TimBukOneCA\n'
#                          'Director Dealings\t@TimBukOneDD\n'
#                          'Home Page \t\t@TimBukOne',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'TimBukOne.com',
#                                          'expanded_url': 'http://www.TimBukOne.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/xxbN0CscSv'}]}},
#           'favourites_count': 1,
#           'follow_request_sent': False,
#           'followers_count': 4601,
#           'following': False,
#           'friends_count': 6,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 4783839322,
#           'id_str': '4783839322',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 26,
#           'location': 'South Africa',
#           'name': 'TimBukOne News',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4783839322/1588258503',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_link_color': '007E4D',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'TimBukOneNEWS',
#           'statuses_count': 10740,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/xxbN0CscSv',
#           'utc_offset': None,
#           'verified': False,
#           'withheld_in_countries': []}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Jul 15 14:15:03 +0000 2021',
#  'display_text_range': [0, 66],
#  'entities': {'hashtags': [{'indices': [0, 13], 'text': 'StandardBank'}],
#               'media': [{'display_url': 'pic.twitter.com/saHwE15EDK',
#                          'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415676286714843137/photo/1',
#                          'id': 1415676285120966659,
#                          'id_str': '1415676285120966659',
#                          'indices': [67, 90],
#                          'media_url': 'http://pbs.twimg.com/media/E6V-FKuUcAMtgyi.png',
#                          'media_url_https': 'https://pbs.twimg.com/media/E6V-FKuUcAMtgyi.png',
#                          'sizes': {'large': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'medium': {'h': 300,
#                                               'resize': 'fit',
#                                               'w': 600},
#                                    'small': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/saHwE15EDK'}],
#               'symbols': [{'indices': [14, 21], 'text': 'JSESBK'}],
#               'urls': [{'display_url': 'dlvr.it/S3nG42',
#                         'expanded_url': 'http://dlvr.it/S3nG42',
#                         'indices': [43, 66],
#                         'url': 'https://t.co/ABD2BX8xUz'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/saHwE15EDK',
#                                   'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415676286714843137/photo/1',
#                                   'id': 1415676285120966659,
#                                   'id_str': '1415676285120966659',
#                                   'indices': [67, 90],
#                                   'media_url': 'http://pbs.twimg.com/media/E6V-FKuUcAMtgyi.png',
#                                   'media_url_https': 'https://pbs.twimg.com/media/E6V-FKuUcAMtgyi.png',
#                                   'sizes': {'large': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'medium': {'h': 300,
#                                                        'resize': 'fit',
#                                                        'w': 600},
#                                             'small': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/saHwE15EDK'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': '#StandardBank $JSESBK - View news article: '
#               'https://t.co/ABD2BX8xUz https://t.co/saHwE15EDK',
#  'geo': None,
#  'id': 1415676286714843137,
#  'id_str': '1415676286714843137',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Jan 12 11:41:09 +0000 2016',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'JSE SENS News\t@TimBukOneSENS\n'
#                          'Cautionary SENS\t@TimBukOneCA\n'
#                          'Director Dealings\t@TimBukOneDD\n'
#                          'Home Page \t\t@TimBukOne',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'TimBukOne.com',
#                                          'expanded_url': 'http://www.TimBukOne.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/xxbN0CscSv'}]}},
#           'favourites_count': 1,
#           'follow_request_sent': False,
#           'followers_count': 4601,
#           'following': False,
#           'friends_count': 6,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 4783839322,
#           'id_str': '4783839322',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 26,
#           'location': 'South Africa',
#           'name': 'TimBukOne News',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4783839322/1588258503',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_link_color': '007E4D',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'TimBukOneNEWS',
#           'statuses_count': 10740,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/xxbN0CscSv',
#           'utc_offset': None,
#           'verified': False,
#           'withheld_in_countries': []}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Jul 15 11:13:48 +0000 2021',
#  'display_text_range': [0, 154],
#  'entities': {'hashtags': [],
#               'symbols': [{'indices': [17, 24], 'text': 'JSEANG'},
#                           {'indices': [32, 39], 'text': 'JSEEXX'},
#                           {'indices': [47, 54], 'text': 'JSEVOD'},
#                           {'indices': [62, 69], 'text': 'JSEAPN'},
#                           {'indices': [96, 103], 'text': 'JSESOL'},
#                           {'indices': [111, 118], 'text': 'JSESBK'},
#                           {'indices': [126, 133], 'text': 'JSEPPH'},
#                           {'indices': [141, 148], 'text': 'JSEAGL'}],
#               'urls': [],
#               'user_mentions': []},
#  'favorite_count': 2,
#  'favorited': False,
#  'full_text': 'Best Performers\n'
#               '\n'
#               '$JSEANG +1.08%\n'
#               '$JSEEXX +0.71%\n'
#               '$JSEVOD +0.60%\n'
#               '$JSEAPN +0.52%\n'
#               '\n'
#               'Worst Performers\n'
#               '\n'
#               '$JSESOL -6.09%\n'
#               '$JSESBK -2.71%\n'
#               '$JSEPPH -1.86%\n'
#               '$JSEAGL-1.72%',
#  'geo': None,
#  'id': 1415630674460037121,
#  'id_str': '1415630674460037121',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'cs',
#  'metadata': {'iso_language_code': 'cs', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web '
#            'App</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon May 26 20:39:54 +0000 2014',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': "South Africa's Multi-Award-Winning Boutique "
#                          'Stockbroker. Rated Best Online Broker and TFSA '
#                          'Provider in 2020. Authorised Financial Services '
#                          'Provider: 45837',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'randswiss.com',
#                                          'expanded_url': 'http://www.randswiss.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/9qhAD1FnN3'}]}},
#           'favourites_count': 241,
#           'follow_request_sent': False,
#           'followers_count': 2435,
#           'following': False,
#           'friends_count': 32,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 2525805978,
#           'id_str': '2525805978',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 34,
#           'location': 'Johannesburg, South Africa',
#           'name': 'Rand Swiss',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2525805978/1601386229',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1045744106901827587/HMJ--SNl_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1045744106901827587/HMJ--SNl_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'RandSwiss',
#           'statuses_count': 6997,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/9qhAD1FnN3',
#           'utc_offset': None,
#           'verified': False,
#           'withheld_in_countries': []}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Jul 15 07:36:04 +0000 2021',
#  'display_text_range': [0, 66],
#  'entities': {'hashtags': [{'indices': [0, 13], 'text': 'StandardBank'}],
#               'media': [{'display_url': 'pic.twitter.com/2tf1v6oCRq',
#                          'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415575878822551558/photo/1',
#                          'id': 1415575877383983107,
#                          'id_str': '1415575877383983107',
#                          'indices': [67, 90],
#                          'media_url': 'http://pbs.twimg.com/media/E6UiwqwVkAM11BL.png',
#                          'media_url_https': 'https://pbs.twimg.com/media/E6UiwqwVkAM11BL.png',
#                          'sizes': {'large': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'medium': {'h': 300,
#                                               'resize': 'fit',
#                                               'w': 600},
#                                    'small': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/2tf1v6oCRq'}],
#               'symbols': [{'indices': [14, 21], 'text': 'JSESBK'}],
#               'urls': [{'display_url': 'dlvr.it/S3m3C9',
#                         'expanded_url': 'http://dlvr.it/S3m3C9',
#                         'indices': [43, 66],
#                         'url': 'https://t.co/baP3TwVkDy'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/2tf1v6oCRq',
#                                   'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415575878822551558/photo/1',
#                                   'id': 1415575877383983107,
#                                   'id_str': '1415575877383983107',
#                                   'indices': [67, 90],
#                                   'media_url': 'http://pbs.twimg.com/media/E6UiwqwVkAM11BL.png',
#                                   'media_url_https': 'https://pbs.twimg.com/media/E6UiwqwVkAM11BL.png',
#                                   'sizes': {'large': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'medium': {'h': 300,
#                                                        'resize': 'fit',
#                                                        'w': 600},
#                                             'small': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/2tf1v6oCRq'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': '#StandardBank $JSESBK - View news article: '
#               'https://t.co/baP3TwVkDy https://t.co/2tf1v6oCRq',
#  'geo': None,
#  'id': 1415575878822551558,
#  'id_str': '1415575878822551558',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Jan 12 11:41:09 +0000 2016',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'JSE SENS News\t@TimBukOneSENS\n'
#                          'Cautionary SENS\t@TimBukOneCA\n'
#                          'Director Dealings\t@TimBukOneDD\n'
#                          'Home Page \t\t@TimBukOne',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'TimBukOne.com',
#                                          'expanded_url': 'http://www.TimBukOne.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/xxbN0CscSv'}]}},
#           'favourites_count': 1,
#           'follow_request_sent': False,
#           'followers_count': 4601,
#           'following': False,
#           'friends_count': 6,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 4783839322,
#           'id_str': '4783839322',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 26,
#           'location': 'South Africa',
#           'name': 'TimBukOne News',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4783839322/1588258503',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_link_color': '007E4D',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'TimBukOneNEWS',
#           'statuses_count': 10740,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/xxbN0CscSv',
#           'utc_offset': None,
#           'verified': False,
#           'withheld_in_countries': []}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Jul 15 06:46:04 +0000 2021',
#  'display_text_range': [0, 66],
#  'entities': {'hashtags': [{'indices': [0, 13], 'text': 'StandardBank'}],
#               'media': [{'display_url': 'pic.twitter.com/fDZqRAUaXv',
#                          'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415563297328295937/photo/1',
#                          'id': 1415563295730245636,
#                          'id_str': '1415563295730245636',
#                          'indices': [67, 90],
#                          'media_url': 'http://pbs.twimg.com/media/E6UXUUcVIAQvxMr.png',
#                          'media_url_https': 'https://pbs.twimg.com/media/E6UXUUcVIAQvxMr.png',
#                          'sizes': {'large': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'medium': {'h': 300,
#                                               'resize': 'fit',
#                                               'w': 600},
#                                    'small': {'h': 300,
#                                              'resize': 'fit',
#                                              'w': 600},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/fDZqRAUaXv'}],
#               'symbols': [{'indices': [14, 21], 'text': 'JSESBK'}],
#               'urls': [{'display_url': 'dlvr.it/S3lwDk',
#                         'expanded_url': 'http://dlvr.it/S3lwDk',
#                         'indices': [43, 66],
#                         'url': 'https://t.co/Iu6GZxavWn'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/fDZqRAUaXv',
#                                   'expanded_url': 'https://twitter.com/TimBukOneNEWS/status/1415563297328295937/photo/1',
#                                   'id': 1415563295730245636,
#                                   'id_str': '1415563295730245636',
#                                   'indices': [67, 90],
#                                   'media_url': 'http://pbs.twimg.com/media/E6UXUUcVIAQvxMr.png',
#                                   'media_url_https': 'https://pbs.twimg.com/media/E6UXUUcVIAQvxMr.png',
#                                   'sizes': {'large': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'medium': {'h': 300,
#                                                        'resize': 'fit',
#                                                        'w': 600},
#                                             'small': {'h': 300,
#                                                       'resize': 'fit',
#                                                       'w': 600},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/fDZqRAUaXv'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': '#StandardBank $JSESBK - View news article: '
#               'https://t.co/Iu6GZxavWn https://t.co/fDZqRAUaXv',
#  'geo': None,
#  'id': 1415563297328295937,
#  'id_str': '1415563297328295937',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Jan 12 11:41:09 +0000 2016',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'JSE SENS News\t@TimBukOneSENS\n'
#                          'Cautionary SENS\t@TimBukOneCA\n'
#                          'Director Dealings\t@TimBukOneDD\n'
#                          'Home Page \t\t@TimBukOne',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'TimBukOne.com',
#                                          'expanded_url': 'http://www.TimBukOne.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/xxbN0CscSv'}]}},
#           'favourites_count': 1,
#           'follow_request_sent': False,
#           'followers_count': 4601,
#           'following': False,
#           'friends_count': 6,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 4783839322,
#           'id_str': '4783839322',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 26,
#           'location': 'South Africa',
#           'name': 'TimBukOne News',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4783839322/1588258503',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/686875699639140353/Lc96QzvC_normal.jpg',
#           'profile_link_color': '007E4D',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'TimBukOneNEWS',
#           'statuses_count': 10740,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/xxbN0CscSv',
#           'utc_offset': None,
#           'verified': False,
#           'withheld_in_countries': []}}

# %%
tweets = Cursor(api.search, q=query, geocode=geocode).items(10)

# %%
tweets
